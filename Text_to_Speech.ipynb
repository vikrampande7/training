# %%
pip install gTTS
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from gtts import gTTS

# %%
from IPython.display import Audio

# %%
tts = gTTS("Yes. We're always interested in improving this generator and one of the best ways to do that is to add new and interesting paragraphs to the generator. If you'd like to contribute some random paragraphs, please contact us.")

# %%
tts.save('1.wav')

# %%
sound_file = '1.wav'

# %%
Audio(sound_file, autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
